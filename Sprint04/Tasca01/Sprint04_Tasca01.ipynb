# %% [markdown]
# # Sprint 04. Tasca 01
# ## By José Manuel Castaño

# %% [markdown]
# ## - Exercici 1
#
# Estandaritza, identifica i enumera cada un dels atributs / variables de l'estructura de l'arxiu "Web_access_log-akumenius.com" que trobaràs al repositori de GitHub "Data-sources".

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %% [markdown]
# ## Preparem la importació:
# - Fem el separador dels diferents camps del log amb Regex
# - Definim els noms de les columnes
# - Eliminem els extrems d'alguns camps que tenen [] i ""
# - Transformem en enters alguns valors numèrics
# - Canviem el - per un NaN

# %%
separador = r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])'
nombre_columnas = ['remote_host', 'IP_client', 'user_identity', 'user_name', 'data_time', 'request', 'status', 'size', 'referer', 'user_agent', 'unknown']

#Funció que elimina els extrems d'alguns camps, [] i ""
def eliminar_extrems(x):
    return x[1:-1]            
convertidor = {'data_time':eliminar_extrems, 'request': eliminar_extrems, 'user_agent':eliminar_extrems, 'referer':eliminar_extrems, 'status':int, 'size':int}

pd.set_option('display.max_colwidth', None)
logs = pd.read_csv('Web_access_log-akumenius.com.txt', sep = separador, names = nombre_columnas, converters=convertidor, na_values='-', engine='python')
logs.head(60)
# Out:
#           remote_host        IP_client  user_identity user_name  \
# 0           localhost        127.0.0.1            NaN       NaN
# 1           localhost        127.0.0.1            NaN       NaN
# 2           localhost        127.0.0.1            NaN       NaN
# 3           localhost        127.0.0.1            NaN       NaN
# 4           localhost        127.0.0.1            NaN       NaN
# 5           localhost        127.0.0.1            NaN       NaN
# 6           localhost        127.0.0.1            NaN       NaN
# 7           localhost        127.0.0.1            NaN       NaN
# 8           localhost        127.0.0.1            NaN       NaN
# 9           localhost        127.0.0.1            NaN       NaN
# 10          localhost        127.0.0.1            NaN       NaN
# 11          localhost        127.0.0.1            NaN       NaN
# 12          localhost        127.0.0.1            NaN       NaN
# 13          localhost        127.0.0.1            NaN       NaN
# 14          localhost        127.0.0.1            NaN       NaN
# 15          localhost        127.0.0.1            NaN       NaN
# 16          localhost        127.0.0.1            NaN       NaN
# 17          localhost        127.0.0.1            NaN       NaN
# 18          localhost        127.0.0.1            NaN       NaN
# 19          localhost        127.0.0.1            NaN       NaN
# 20          localhost        127.0.0.1            NaN       NaN
# 21          localhost        127.0.0.1            NaN       NaN
# 22  www.akumenius.com    66.249.76.216            NaN       NaN
# 23  www.akumenius.com    66.249.76.216            NaN       NaN
# 24  www.akumenius.com    66.249.76.216            NaN       NaN
# 25  www.akumenius.com    66.249.76.216            NaN       NaN
# 26  www.akumenius.com    66.249.76.216            NaN       NaN
# 27  www.akumenius.com    66.249.76.216            NaN       NaN
# 28  www.akumenius.com    66.249.76.216            NaN       NaN
# 29  www.akumenius.com    66.249.76.216            NaN       NaN
# 30  www.akumenius.com    66.249.76.216            NaN       NaN
# 31  www.akumenius.com    66.249.76.216            NaN       NaN
# 32  www.akumenius.com    66.249.76.216            NaN       NaN
# 33  www.akumenius.com    66.249.76.216            NaN       NaN
# 34  www.akumenius.com    66.249.76.216            NaN       NaN
# 35  www.akumenius.com    66.249.76.216            NaN       NaN
# 36  www.akumenius.com     5.255.253.53            NaN       NaN
# 37  www.akumenius.com    66.249.76.216            NaN       NaN
# 38  www.akumenius.com    66.249.76.216            NaN       NaN
# 39  www.akumenius.com    66.249.76.216            NaN       NaN
# 40  www.akumenius.com    66.249.76.216            NaN       NaN
# 41  www.akumenius.com    157.55.35.112            NaN       NaN
# 42  www.akumenius.com    66.249.76.216            NaN       NaN
# 43  www.akumenius.com    66.249.76.216            NaN       NaN
# 44  www.akumenius.com  193.111.141.116            NaN       NaN
# 45  www.akumenius.com    66.249.76.216            NaN       NaN
# 46  www.akumenius.com    66.249.76.216            NaN       NaN
# 47  www.akumenius.com    66.249.76.216            NaN       NaN
# 48  www.akumenius.com    66.249.76.216            NaN       NaN
# 49  www.akumenius.com    66.249.76.216            NaN       NaN
# 50  www.akumenius.com    66.249.76.216            NaN       NaN
# 51  www.akumenius.com    66.249.76.216            NaN       NaN
# 52  www.akumenius.com    66.249.76.216            NaN       NaN
# 53  www.akumenius.com    66.249.76.216            NaN       NaN
# 54  www.akumenius.com    66.249.76.216            NaN       NaN
# 55  www.akumenius.com    66.249.76.216            NaN       NaN
# 56  www.akumenius.com    66.249.76.216            NaN       NaN
# 57  www.akumenius.com    66.249.76.216            NaN       NaN
# 58  www.akumenius.com    66.249.76.216            NaN       NaN
# 59  www.akumenius.com    66.249.76.216            NaN       NaN
#
#                      data_time  \
# 0   23/Feb/2014:03:10:31 +0100
# 1   23/Feb/2014:03:10:31 +0100
# 2   23/Feb/2014:03:10:31 +0100
# 3   23/Feb/2014:03:10:31 +0100
# 4   23/Feb/2014:03:10:31 +0100
# 5   23/Feb/2014:03:10:31 +0100
# 6   23/Feb/2014:03:10:31 +0100
# 7   23/Feb/2014:03:10:31 +0100
# 8   23/Feb/2014:03:10:31 +0100
# 9   23/Feb/2014:03:10:31 +0100
# 10  23/Feb/2014:03:10:31 +0100
# 11  23/Feb/2014:03:10:31 +0100
# 12  23/Feb/2014:03:10:31 +0100
# 13  23/Feb/2014:03:10:31 +0100
# 14  23/Feb/2014:03:10:31 +0100
# 15  23/Feb/2014:03:10:31 +0100
# 16  23/Feb/2014:03:10:31 +0100
# 17  23/Feb/2014:03:10:31 +0100
# 18  23/Feb/2014:03:10:31 +0100
# 19  23/Feb/2014:03:10:31 +0100
# 20  23/Feb/2014:03:10:31 +0100
# 21  23/Feb/2014:03:10:31 +0100
# 22  23/Feb/2014:03:10:31 +0100
# 23  23/Feb/2014:03:10:33 +0100
# 24  23/Feb/2014:03:10:35 +0100
# 25  23/Feb/2014:03:10:38 +0100
# 26  23/Feb/2014:03:10:39 +0100
# 27  23/Feb/2014:03:10:40 +0100
# 28  23/Feb/2014:03:10:42 +0100
# 29  23/Feb/2014:03:10:45 +0100
# 30  23/Feb/2014:03:10:46 +0100
# 31  23/Feb/2014:03:10:47 +0100
# 32  23/Feb/2014:03:10:49 +0100
# 33  23/Feb/2014:03:10:52 +0100
# 34  23/Feb/2014:03:10:53 +0100
# 35  23/Feb/2014:03:10:54 +0100
# 36  23/Feb/2014:03:10:56 +0100
# 37  23/Feb/2014:03:10:56 +0100
# 38  23/Feb/2014:03:10:59 +0100
# 39  23/Feb/2014:03:11:01 +0100
# 40  23/Feb/2014:03:11:01 +0100
# 41  23/Feb/2014:03:11:02 +0100
# 42  23/Feb/2014:03:11:03 +0100
# 43  23/Feb/2014:03:11:06 +0100
# 44  23/Feb/2014:03:11:07 +0100
# 45  23/Feb/2014:03:11:08 +0100
# 46  23/Feb/2014:03:11:09 +0100
# 47  23/Feb/2014:03:11:10 +0100
# 48  23/Feb/2014:03:11:13 +0100
# 49  23/Feb/2014:03:11:14 +0100
# 50  23/Feb/2014:03:11:15 +0100
# 51  23/Feb/2014:03:11:16 +0100
# 52  23/Feb/2014:03:11:17 +0100
# 53  23/Feb/2014:03:11:20 +0100
# 54  23/Feb/2014:03:11:22 +0100
# 55  23/Feb/2014:03:11:23 +0100
# 56  23/Feb/2014:03:11:25 +0100
# 57  23/Feb/2014:03:11:27 +0100
# 58  23/Feb/2014:03:11:27 +0100
# 59  23/Feb/2014:03:11:29 +0100
#
#                                                                                                                                             request  \
# 0                                                                                                                                OPTIONS * HTTP/1.0
# 1                                                                                                                                OPTIONS * HTTP/1.0
# 2                                                                                                                                OPTIONS * HTTP/1.0
# 3                                                                                                                                OPTIONS * HTTP/1.0
# 4                                                                                                                                OPTIONS * HTTP/1.0
# 5                                                                                                                                OPTIONS * HTTP/1.0
# 6                                                                                                                                OPTIONS * HTTP/1.0
# 7                                                                                                                                OPTIONS * HTTP/1.0
# 8                                                                                                                                OPTIONS * HTTP/1.0
# 9                                                                                                                                OPTIONS * HTTP/1.0
# 10                                                                                                                               OPTIONS * HTTP/1.0
# 11                                                                                                                               OPTIONS * HTTP/1.0
# 12                                                                                                                               OPTIONS * HTTP/1.0
# 13                                                                                                                               OPTIONS * HTTP/1.0
# 14                                                                                                                               OPTIONS * HTTP/1.0
# 15                                                                                                                               OPTIONS * HTTP/1.0
# 16                                                                                                                               OPTIONS * HTTP/1.0
# 17                                                                                                                               OPTIONS * HTTP/1.0
# 18                                                                                                                               OPTIONS * HTTP/1.0
# 19                                                                                                                               OPTIONS * HTTP/1.0
# 20                                                                                                                               OPTIONS * HTTP/1.0
# 21                                                                                                                               OPTIONS * HTTP/1.0
# 22                                                GET /hoteles-baratos/ofertas-hotel-Club-&-Hotel-Letoonia--en-Fethiye-8460b-destinos.html HTTP/1.1
# 23                                                     GET /hoteles-baratos/ofertas-hotel-Metropolis-Hotel-en-Kaunas-210244b-destinos.html HTTP/1.1
# 24                                           GET /hoteles-baratos/ofertas-hotel-Faena-Hotel-Buenos-Aires-en-Downtown-129723b-destinos.html HTTP/1.1
# 25                                       GET /hoteles-baratos/ofertas-hotel-Kensington-Townhouse-London-en-Kensington-54356b-destinos.html HTTP/1.1
# 26                                                GET /destinos-baratos/destinosEstrelles/hoteles-en-Invermere_CANAD%C3%81-con-4-estrellas HTTP/1.1
# 27  GET /hoteles-baratos/ofertas-hotel-Howard-Jhonson-hotel-&-Spa--Villa-Gral-Belgrano-en-Villa%20General%20Belgrano-146416b-destinos.html HTTP/1.1
# 28                                                  GET /hoteles-baratos/ofertas-hotel-Princesa-Sofia-en-Diagonal%20S.-4013b-destinos.html HTTP/1.1
# 29                                                        GET /hoteles-baratos/ofertas-hotel-Kfar-Giladi-en-Tiberias-121085b-destinos.html HTTP/1.1
# 30                                                GET /destinos-baratos/destinosEstrelles/hoteles-en-Skanderborg_DINAMARCA-con-5-estrellas HTTP/1.1
# 31                                              GET /hoteles-baratos/ofertas-hotel-Casual-Hotel-Valencia-en-Valencia-205435b-destinos.html HTTP/1.1
# 32                                                               GET /hoteles-baratos/ofertas-hotel-Lucky-2-en-Hanoi-146288b-destinos.html HTTP/1.1
# 33                                             GET /hoteles-baratos/ofertas-hotel-Natali-Torremolinos-en-Torremolinos-22598b-destinos.html HTTP/1.1
# 34                                                GET /destinos-baratos/destinosEstrelles/hoteles-en-Villarcayo_ESPA%C3%91A-con-1-estrella HTTP/1.1
# 35                                    GET /hoteles-baratos/ofertas-hotel-Hotel-Costa-del-Sol-Cartagena--en-Cartagena-106856b-destinos.html HTTP/1.1
# 36                                    GET /destinos-baratos/hoteles-baratos/ofertas-hotel-Osterley-Park-en-Brentford-104320b-destinos.html HTTP/1.1
# 37                             GET /hoteles-baratos/ofertas-hotel-Quintessia-&-Spa-(Ex-Domaine-D'Orvault)-en-Orvault-170129b-destinos.html HTTP/1.1
# 38                                           GET /hoteles-baratos/ofertas-hotel-Cill-Aodain-Court-Hotel-en-Kiltimagh-143726b-destinos.html HTTP/1.1
# 39                                                GET /destinos-baratos/destinosEstrelles/hoteles-en-Mellrichstadt_ALEMANIA-con-1-estrella HTTP/1.1
# 40                                            GET /hoteles-baratos/ofertas-hotel-Venetur-Hotel-del-Lago--en-Maracaibo-72209b-destinos.html HTTP/1.1
# 41    GET /destinos-baratos/destinos-caracteristicas/hoteles-baratos-en-Dubai_EMIRATOS%20ARABES%20UNIDOS-con-Actividades-de-animaci%C3%B3n HTTP/1.1
# 42                                                GET /hoteles-baratos/ofertas-hotel-Ametlla-Mar-en-Ametlla%20de%20Mar-3546b-destinos.html HTTP/1.1
# 43                                                 GET /hoteles-baratos/ofertas-hotel-Abba-Comillas-Golf-en-Comillas-142446b-destinos.html HTTP/1.1
# 44                                      GET /hoteles-baratos/ofertas-hotel-Roque-Monica-Apartamentos-en-Los%20Llanos-133556b-destinos.html HTTP/1.1
# 45                                                 GET /hoteles-baratos/ofertas-hotel-Westin-Panama-en-Panama%20City-190988b-destinos.html HTTP/1.1
# 46                                                GET /destinos-baratos/destinosEstrelles/hoteles-en-Wainwright_CANAD%C3%81-con-1-estrella HTTP/1.1
# 47                                                       GET /hoteles-baratos/ofertas-hotel-Kenia-Nevada-en-Pradollano-2717b-destinos.html HTTP/1.1
# 48                                        GET /destinos-caracteristicas/hoteles-baratos-en-Machu-Pichu_PERU-con-Ba%C3%B1era-de-hidromasaje HTTP/1.1
# 49                                                           GET /hoteles-baratos/ofertas-hotel-Tugcu-Hotel-en-Bursa-162580b-destinos.html HTTP/1.1
# 50                                             GET /hoteles-baratos/ofertas-hotel-Hilton-London-Hyde-Park-en-Bayswater-7566b-destinos.html HTTP/1.1
# 51                                                GET /destinos-baratos/destinosEstrelles/hoteles-en-Schmiedeberg_ALEMANIA-con-5-estrellas HTTP/1.1
# 52                                           GET /hoteles-baratos/ofertas-hotel-Luna-Alpinus-Falesia-Suites-en-Algarve_PORTUGAL-8542b.html HTTP/1.1
# 53                                                GET /hoteles-baratos/ofertas-hotel-Cisneros-en-Alcala%20de%20Henares-4397b-destinos.html HTTP/1.1
# 54                                                            GET /hoteles-baratos/ofertas-hoteles-todo-incluido-en-mijas_ESPA%C3%91A.html HTTP/1.1
# 55                                                GET /destinos-baratos/destinosEstrelles/hoteles-en-Gironella_ESPA%C3%91A-con-5-estrellas HTTP/1.1
# 56                                                            GET /hoteles-baratos/ofertas-hoteles-todo-incluido-en-salou_ESPA%C3%91A.html HTTP/1.1
# 57                                                     GET /hoteles-baratos/ofertas-hoteles-todo-incluido-en-santa-susana_ESPA%C3%91A.html HTTP/1.1
# 58                                                                 GET /destinosEstrelles/hoteles-en-Muchamiel_ESPA%C3%91A-con-5-estrellas HTTP/1.1
# 59                                                          GET /hoteles-baratos/ofertas-hoteles-todo-incluido-en-cartaya_ESPA%C3%91A.html HTTP/1.1
#
#     status   size referer  \
# 0      200    NaN     NaN
# 1      200    NaN     NaN
# 2      200    NaN     NaN
# 3      200    NaN     NaN
# 4      200    NaN     NaN
# 5      200    NaN     NaN
# 6      200    NaN     NaN
# 7      200    NaN     NaN
# 8      200    NaN     NaN
# 9      200    NaN     NaN
# 10     200    NaN     NaN
# 11     200    NaN     NaN
# 12     200    NaN     NaN
# 13     200    NaN     NaN
# 14     200    NaN     NaN
# 15     200    NaN     NaN
# 16     200    NaN     NaN
# 17     200    NaN     NaN
# 18     200    NaN     NaN
# 19     200    NaN     NaN
# 20     200    NaN     NaN
# 21     200    NaN     NaN
# 22     404   3100     NaN
# 23     404   3100     NaN
# 24     404   3100     NaN
# 25     404   3100     NaN
# 26     200   8811     NaN
# 27     404   3100     NaN
# 28     404   3100     NaN
# 29     404   3100     NaN
# 30     200   8816     NaN
# 31     404   3100     NaN
# 32     404   3100     NaN
# 33     404   3100     NaN
# 34     200   8810     NaN
# 35     404   3100     NaN
# 36     404   3100     NaN
# 37     404   3100     NaN
# 38     404   3100     NaN
# 39     200   8812     NaN
# 40     404   3100     NaN
# 41     200  14818     NaN
# 42     404   3100     NaN
# 43     404   3100     NaN
# 44     404  17750     NaN
# 45     404   3100     NaN
# 46     200   8807     NaN
# 47     404   3100     NaN
# 48     200   9914     NaN
# 49     404   3100     NaN
# 50     404   3100     NaN
# 51     200   8817     NaN
# 52     200   6118     NaN
# 53     404   3100     NaN
# 54     200   6708     NaN
# 55     200   8812     NaN
# 56     200   5645     NaN
# 57     200   6144     NaN
# 58     200   8806     NaN
# 59     200   4261     NaN
#
#                                                                   user_agent  \
# 0                                         Apache (internal dummy connection)
# 1                                         Apache (internal dummy connection)
# 2                                         Apache (internal dummy connection)
# 3                                         Apache (internal dummy connection)
# 4                                         Apache (internal dummy connection)
# 5                                         Apache (internal dummy connection)
# 6                                         Apache (internal dummy connection)
# 7                                         Apache (internal dummy connection)
# 8                                         Apache (internal dummy connection)
# 9                                         Apache (internal dummy connection)
# 10                                        Apache (internal dummy connection)
# 11                                        Apache (internal dummy connection)
# 12                                        Apache (internal dummy connection)
# 13                                        Apache (internal dummy connection)
# 14                                        Apache (internal dummy connection)
# 15                                        Apache (internal dummy connection)
# 16                                        Apache (internal dummy connection)
# 17                                        Apache (internal dummy connection)
# 18                                        Apache (internal dummy connection)
# 19                                        Apache (internal dummy connection)
# 20                                        Apache (internal dummy connection)
# 21                                        Apache (internal dummy connection)
# 22  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 23  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 24  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 25  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 26  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 27  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 28  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 29  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 30  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 31  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 32  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 33  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 34  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 35  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 36          Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)
# 37  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 38  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 39  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 40  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 41   Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm)
# 42  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 43  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 44          Mozilla/5.0 (X11; Linux i686; rv:6.0) Gecko/20100101 Firefox/6.0
# 45  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 46  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 47  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 48  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 49  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 50  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 51  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 52  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 53  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 54  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 55  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 56  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 57  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 58  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# 59  Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
#
#    unknown
# 0   VLOG=-
# 1   VLOG=-
# 2   VLOG=-
# 3   VLOG=-
# 4   VLOG=-
# 5   VLOG=-
# 6   VLOG=-
# 7   VLOG=-
# 8   VLOG=-
# 9   VLOG=-
# 10  VLOG=-
# 11  VLOG=-
# 12  VLOG=-
# 13  VLOG=-
# 14  VLOG=-
# 15  VLOG=-
# 16  VLOG=-
# 17  VLOG=-
# 18  VLOG=-
# 19  VLOG=-
# 20  VLOG=-
# 21  VLOG=-
# 22  VLOG=-
# 23  VLOG=-
# 24  VLOG=-
# 25  VLOG=-
# 26  VLOG=-
# 27  VLOG=-
# 28  VLOG=-
# 29  VLOG=-
# 30  VLOG=-
# 31  VLOG=-
# 32  VLOG=-
# 33  VLOG=-
# 34  VLOG=-
# 35  VLOG=-
# 36  VLOG=-
# 37  VLOG=-
# 38  VLOG=-
# 39  VLOG=-
# 40  VLOG=-
# 41  VLOG=-
# 42  VLOG=-
# 43  VLOG=-
# 44  VLOG=-
# 45  VLOG=-
# 46  VLOG=-
# 47  VLOG=-
# 48  VLOG=-
# 49  VLOG=-
# 50  VLOG=-
# 51  VLOG=-
# 52  VLOG=-
# 53  VLOG=-
# 54  VLOG=-
# 55  VLOG=-
# 56  VLOG=-
# 57  VLOG=-
# 58  VLOG=-
# 59  VLOG=-

# %% [markdown]
# ## - Exercici 2
#
# Neteja, preprocesa, estructura i transforma (dataframe) les dades del registre d'Accés a la web.

# %% [markdown]
# Analitzem el contingut dels camps per tal de detectar camps susceptibles de ser eliminats

# %%
logs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261873 entries, 0 to 261872
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   remote_host    261873 non-null  object
#  1   IP_client      261873 non-null  object
#  2   user_identity  0 non-null       float64
#  3   user_name      27 non-null      object
#  4   data_time      261873 non-null  object
#  5   request        261836 non-null  object
#  6   status         261873 non-null  int64
#  7   size           219538 non-null  object
#  8   referer        162326 non-null  object
#  9   user_agent     261654 non-null  object
#  10  unknown        261873 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 22.0+ MB

# %%
logs.isnull().sum()
# Out:
# remote_host           0
# IP_client             0
# user_identity    261873
# user_name        261846
# data_time             0
# request              37
# status                0
# size              42335
# referer           99547
# user_agent          219
# unknown               0
# dtype: int64

# %%
logs['unknown'].value_counts()
# Out:
# VLOG=-    261873
# Name: unknown, dtype: int64

# %% [markdown]
# Veiem que el camp **user_identity** té tots el valors nulls i que el camp **unknown** tots els registres tenen el mateix valor.
# Decidim per tant eliminar-los

# %%
logs.drop(['user_identity', 'unknown'], axis=1, inplace=True)
logs.head()
# Out:
#   remote_host  IP_client user_name                   data_time  \
# 0   localhost  127.0.0.1       NaN  23/Feb/2014:03:10:31 +0100
# 1   localhost  127.0.0.1       NaN  23/Feb/2014:03:10:31 +0100
# 2   localhost  127.0.0.1       NaN  23/Feb/2014:03:10:31 +0100
# 3   localhost  127.0.0.1       NaN  23/Feb/2014:03:10:31 +0100
# 4   localhost  127.0.0.1       NaN  23/Feb/2014:03:10:31 +0100
#
#               request  status size referer                          user_agent
# 0  OPTIONS * HTTP/1.0     200  NaN     NaN  Apache (internal dummy connection)
# 1  OPTIONS * HTTP/1.0     200  NaN     NaN  Apache (internal dummy connection)
# 2  OPTIONS * HTTP/1.0     200  NaN     NaN  Apache (internal dummy connection)
# 3  OPTIONS * HTTP/1.0     200  NaN     NaN  Apache (internal dummy connection)
# 4  OPTIONS * HTTP/1.0     200  NaN     NaN  Apache (internal dummy connection)

# %% [markdown]
# Desdoblem el camp **data_time** en 3 nous camps: **date, time i time_zone**.
# Eliminem el camp **data_time**

# %%
logs.insert(4,'date',logs['data_time'].str.split(':',1).str[0])
logs.insert(5,'time',logs['data_time'].str.slice(-14,-5))
logs.insert(6, 'time_zone',logs['data_time'].str.slice(-5))  
logs.drop(['data_time'], axis=1, inplace=True)               #Eliminem el camp data_time
logs.head()
# Out:
#   remote_host  IP_client user_name         date       time time_zone  \
# 0   localhost  127.0.0.1       NaN  23/Feb/2014  03:10:31      +0100
# 1   localhost  127.0.0.1       NaN  23/Feb/2014  03:10:31      +0100
# 2   localhost  127.0.0.1       NaN  23/Feb/2014  03:10:31      +0100
# 3   localhost  127.0.0.1       NaN  23/Feb/2014  03:10:31      +0100
# 4   localhost  127.0.0.1       NaN  23/Feb/2014  03:10:31      +0100
#
#               request  status size referer                          user_agent
# 0  OPTIONS * HTTP/1.0     200  NaN     NaN  Apache (internal dummy connection)
# 1  OPTIONS * HTTP/1.0     200  NaN     NaN  Apache (internal dummy connection)
# 2  OPTIONS * HTTP/1.0     200  NaN     NaN  Apache (internal dummy connection)
# 3  OPTIONS * HTTP/1.0     200  NaN     NaN  Apache (internal dummy connection)
# 4  OPTIONS * HTTP/1.0     200  NaN     NaN  Apache (internal dummy connection)

# %% [markdown]
# Desdoblem el camp **request** en 3 camps: **type_request, request i protocol**

# %%
logs.insert(6,'type_request',logs['request'].str.split(' ').str[0])
logs.insert(8,'protocol',logs['request'].str.split(' ').str[2])
logs['request']=logs['request'].str.split(' ').str[1]
logs.head()
# Out:
#   remote_host  IP_client user_name         date       time time_zone  \
# 0   localhost  127.0.0.1       NaN  23/Feb/2014  03:10:31      +0100
# 1   localhost  127.0.0.1       NaN  23/Feb/2014  03:10:31      +0100
# 2   localhost  127.0.0.1       NaN  23/Feb/2014  03:10:31      +0100
# 3   localhost  127.0.0.1       NaN  23/Feb/2014  03:10:31      +0100
# 4   localhost  127.0.0.1       NaN  23/Feb/2014  03:10:31      +0100
#
#   type_request request  protocol  status size referer  \
# 0      OPTIONS       *  HTTP/1.0     200  NaN     NaN
# 1      OPTIONS       *  HTTP/1.0     200  NaN     NaN
# 2      OPTIONS       *  HTTP/1.0     200  NaN     NaN
# 3      OPTIONS       *  HTTP/1.0     200  NaN     NaN
# 4      OPTIONS       *  HTTP/1.0     200  NaN     NaN
#
#                            user_agent
# 0  Apache (internal dummy connection)
# 1  Apache (internal dummy connection)
# 2  Apache (internal dummy connection)
# 3  Apache (internal dummy connection)
# 4  Apache (internal dummy connection)

# %% [markdown]
# ## - Exercici 3
#
# Geolocalitza les IP's.

# %% [markdown]
# Per geolocalitzar utilitzem el mòdul ip2geotools.
# Busquem la freqüencia de IP's i en funció de la quantitat de ip's diferents que ens surtin, establirem un criteri per tal de geolocalitzar només les més repetides, ja que el procés de geolocalitzar és lent

# %%
from ip2geotools.databases.noncommercial import DbIpCity

# %%
logs['IP_client'].value_counts()
# Out:
# 66.249.76.216      46382
# 80.28.221.123      14725
# 127.0.0.1          13892
# 217.125.71.222      5201
# 66.249.75.148       3558
#                    ...
# 84.123.150.27          1
# 217.130.150.116        1
# 202.46.52.23           1
# 216.151.130.170        1
# 206.198.5.33           1
# Name: IP_client, Length: 2921, dtype: int64

# %% [markdown]
# Creem un nou df **Ip_procedencia** on tindrem les IP's, les visites i les dades de geolocalització

# %%
IP_procedencia=logs['IP_client'].value_counts().rename_axis('IP').reset_index(name='visits')
IP_procedencia
# Out:
#                    IP  visits
# 0       66.249.76.216   46382
# 1       80.28.221.123   14725
# 2           127.0.0.1   13892
# 3      217.125.71.222    5201
# 4       66.249.75.148    3558
# ...               ...     ...
# 2916    84.123.150.27       1
# 2917  217.130.150.116       1
# 2918     202.46.52.23       1
# 2919  216.151.130.170       1
# 2920     206.198.5.33       1
#
# [2921 rows x 2 columns]

# %%
IP_procedencia.describe().round(2)
# Out:
#          visits
# count   2921.00
# mean      89.65
# std      949.37
# min        1.00
# 25%        2.00
# 50%       31.00
# 75%       81.00
# max    46382.00

# %% [markdown]
# Veiem que en total tenim 2921 visites úniques. La mitja de visites per IP es de 89.65 i que 81 IP's realitzen el 75% del total de visites (3º cuartil).
# Com que el procès de geolocalització és lent, ens quedarem només amb les 81 ip's amb més visites i són les que geolocalitzarem

# %%
IP_procedencia.drop(range(82,2921), axis=0, inplace=True)
IP_procedencia
# Out:
#                 IP  visits
# 0    66.249.76.216   46382
# 1    80.28.221.123   14725
# 2        127.0.0.1   13892
# 3   217.125.71.222    5201
# 4    66.249.75.148    3558
# ..             ...     ...
# 77   208.43.225.85     313
# 78     83.43.71.59     310
# 79     85.55.167.1     309
# 80  193.111.141.52     301
# 81  188.119.219.26     289
#
# [82 rows x 2 columns]

# %% [markdown]
# Utilitzem la llibreria ip2geotools per tal de geolocalitzar les Ip's

# %%
#Creem diferents funcions que retornen latitude, longitude, city, region, country en funció del paàmetre ip
def latitude(ip):
    try:
        g=DbIpCity.get(ip,api_key='free')
        return g.latitude
    except:
        return np.nan

def longitude(ip):
    try:
        g=DbIpCity.get(ip,api_key='free')
        return g.longitude
    except:
        return np.nan   

def city(ip):
    try:
        g=DbIpCity.get(ip,api_key='free')
        return g.city
    except:
        return np.nan
    
def region(ip):
    try:
        g=DbIpCity.get(ip,api_key='free')
        return g.region
    except:
        return np.nan 

def country(ip):
    try:
        g=DbIpCity.get(ip,api_key='free')
        return g.country
    except:
        return np.nan
    
latitude('176.31.255.177')
# Out:
# 50.6915893

# %% [markdown]
# Creem els nous camps amb la informació de geolocalització

# %%
IP_procedencia['latitude'] = IP_procedencia['IP'].apply(latitude)
IP_procedencia['longitude'] = IP_procedencia['IP'].apply(longitude)
IP_procedencia['city'] = IP_procedencia['IP'].apply(city)
IP_procedencia['region'] = IP_procedencia['IP'].apply(region)
IP_procedencia['country'] = IP_procedencia['IP'].apply(country)
IP_procedencia
# Out:
#                 IP  visits   latitude   longitude  \
# 0    66.249.76.216   46382  37.389389 -122.083210
# 1    80.28.221.123   14725  40.416705   -3.703582
# 2        127.0.0.1   13892  36.733438 -119.833235
# 3   217.125.71.222    5201  40.416705   -3.703582
# 4    66.249.75.148    3558  37.389389 -122.083210
# ..             ...     ...        ...         ...
# 77   208.43.225.85     313  38.895037  -77.036543
# 78     83.43.71.59     310  40.416705   -3.703582
# 79     85.55.167.1     309  40.434653   -3.814834
# 80  193.111.141.52     301        NaN         NaN
# 81  188.119.219.26     289  41.382894    2.177432
#
#                                  city                region country
# 0                       Mountain View            California      US
# 1                              Madrid                Madrid      ES
# 2                                None                  None      ZZ
# 3                              Madrid                Madrid      ES
# 4                       Mountain View            California      US
# ..                                ...                   ...     ...
# 77                    Washington D.C.  District of Columbia      US
# 78                             Madrid                Madrid      ES
# 79                 Pozuelo de Alarcón                Madrid      ES
# 80  Amsterdam (Nieuwmarkt en Lastage)         North Holland      NL
# 81                          Barcelona             Catalonia      ES
#
# [82 rows x 7 columns]

# %%
Mirem de quins contries provenen

# %%
IP_procedencia.groupby(['country'])['visits'].agg(sum).sort_values(ascending=False)
# Out:
# country
# US    62500
# ES    46937
# ZZ    13892
# SE     1821
# FR     1044
# IT      831
# DE      552
# VG      426
# NL      301
# Name: visits, dtype: int64
