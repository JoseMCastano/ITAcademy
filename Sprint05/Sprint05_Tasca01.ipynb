# %% [markdown]
# # Sprint 05. Tasca 01. Mètodes de mostreig
# ## By José Manuel Castaño

# %% [markdown]
# ## - Exercici 1
#
# Agafa un conjunt de dades de tema esportiu que t'agradi. Realitza un mostreig de les dades generant una mostra aleatòria simple i una mostra sistemàtica.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Agafo el dataset credit cards customers amb informació d'usuaris de credit cards

# %%
creditcard = pd.read_csv('BankChurners.csv')

# %%
creditcard.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# 1              44  ...        8256.0                  864           7392.0
# 2              36  ...        3418.0                    0           3418.0
# 3              34  ...        3313.0                 2517            796.0
# 4              21  ...        4716.0                    0           4716.0
#
#    Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0                 1.335             1144              42                1.625
# 1                 1.541             1291              33                3.714
# 2                 2.594             1887              20                2.333
# 3                 1.405             1171              20                2.333
# 4                 2.175              816              28                2.500
#
#    Avg_Utilization_Ratio  \
# 0                  0.061
# 1                  0.105
# 2                  0.000
# 3                  0.760
# 4                  0.000
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                           0.000093
# 1                                           0.000057
# 2                                           0.000021
# 3                                           0.000134
# 4                                           0.000022
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 0                                            0.99991
# 1                                            0.99994
# 2                                            0.99998
# 3                                            0.99987
# 4                                            0.99998
#
# [5 rows x 23 columns]

# %% [markdown]
# Eliminem algunes columnes per recomanació del creador de l'arxiu.
# Cambiem alguns noms de les columnes per fer-los més inteligibles i operatius

# %%
creditcard.drop(creditcard.columns[[16,19,21,22]], axis='columns', inplace=True)

# %%
creditcard.rename(columns={'Total_Relationship_Count':'Total_Products', 'Months_Inactive_12_mon':'Months_Inactive','Contacts_Count_12_mon':'Contacts_Count',
                           'Total_Revolving_Bal':'Revolving', 'Avg_Open_To_Buy':'Open_To_Buy','Total_Trans_Ct':'Transaction_Count','Total_Trans_Amt':'Transaction_Amount',
                           'Avg_Utilization_Ratio':'Utilization_Ratio'}, inplace=True)
creditcard.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  Total_Products  Months_Inactive  Contacts_Count  \
# 0              39               5                1               3
# 1              44               6                1               2
# 2              36               4                1               0
# 3              34               3                4               1
# 4              21               5                1               0
#
#    Credit_Limit  Revolving  Open_To_Buy  Transaction_Amount  \
# 0       12691.0        777      11914.0                1144
# 1        8256.0        864       7392.0                1291
# 2        3418.0          0       3418.0                1887
# 3        3313.0       2517        796.0                1171
# 4        4716.0          0       4716.0                 816
#
#    Transaction_Count  Utilization_Ratio
# 0                 42              0.061
# 1                 33              0.105
# 2                 20              0.000
# 3                 20              0.760
# 4                 28              0.000

# %% [markdown]
# Abans de començar el mostreig, fem un petit anàlisi de les dades

# %%
creditcard.isnull().sum()
# Out:
# CLIENTNUM             0
# Attrition_Flag        0
# Customer_Age          0
# Gender                0
# Dependent_count       0
# Education_Level       0
# Marital_Status        0
# Income_Category       0
# Card_Category         0
# Months_on_book        0
# Total_Products        0
# Months_Inactive       0
# Contacts_Count        0
# Credit_Limit          0
# Revolving             0
# Open_To_Buy           0
# Transaction_Amount    0
# Transaction_Count     0
# Utilization_Ratio     0
# dtype: int64

# %% [markdown]
# No hi ha nulls

# %%
creditcard.describe().round(2)
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04      10127.00         10127.00        10127.00
# mean   7.391776e+08         46.33             2.35           35.93
# std    3.690378e+07          8.02             1.30            7.99
# min    7.080821e+08         26.00             0.00           13.00
# 25%    7.130368e+08         41.00             1.00           31.00
# 50%    7.179264e+08         46.00             2.00           36.00
# 75%    7.731435e+08         52.00             3.00           40.00
# max    8.283431e+08         73.00             5.00           56.00
#
#        Total_Products  Months_Inactive  Contacts_Count  Credit_Limit  \
# count        10127.00         10127.00        10127.00      10127.00
# mean             3.81             2.34            2.46       8631.95
# std              1.55             1.01            1.11       9088.78
# min              1.00             0.00            0.00       1438.30
# 25%              3.00             2.00            2.00       2555.00
# 50%              4.00             2.00            2.00       4549.00
# 75%              5.00             3.00            3.00      11067.50
# max              6.00             6.00            6.00      34516.00
#
#        Revolving  Open_To_Buy  Transaction_Amount  Transaction_Count  \
# count   10127.00     10127.00            10127.00           10127.00
# mean     1162.81      7469.14             4404.09              64.86
# std       814.99      9090.69             3397.13              23.47
# min         0.00         3.00              510.00              10.00
# 25%       359.00      1324.50             2155.50              45.00
# 50%      1276.00      3474.00             3899.00              67.00
# 75%      1784.00      9859.00             4741.00              81.00
# max      2517.00     34516.00            18484.00             139.00
#
#        Utilization_Ratio
# count           10127.00
# mean                0.27
# std                 0.28
# min                 0.00
# 25%                 0.02
# 50%                 0.18
# 75%                 0.50
# max                 1.00

# %%
plt.rcParams["figure.figsize"] = (18, 7)
creditcard['Customer_Age'].value_counts().sort_index(ascending=True).plot(kind='bar', title='Customer age');

# %% [markdown]
# Veiem una distribució unimodal, simètrica, amb la mitja i mediana molt similars.

# %%
creditcard['Gender'].value_counts(normalize=True)
# Out:
# F    0.529081
# M    0.470919
# Name: Gender, dtype: float64

# %%
creditcard['Education_Level'].value_counts(normalize=True)
# Out:
# Graduate         0.308877
# High School      0.198776
# Unknown          0.149995
# Uneducated       0.146835
# College          0.100030
# Post-Graduate    0.050953
# Doctorate        0.044534
# Name: Education_Level, dtype: float64

# %%
creditcard['Income_Category'].value_counts(normalize=True)
# Out:
# Less than $40K    0.351634
# $40K - $60K       0.176755
# $80K - $120K      0.151575
# $60K - $80K       0.138442
# Unknown           0.109805
# $120K +           0.071788
# Name: Income_Category, dtype: float64

# %% [markdown]
# Veiem que el 35% dels ingressos són alts (>80k) i el 35% són baixos (<40k)

# %%
creditcard['Marital_Status'].value_counts(normalize=True)
# Out:
# Married     0.462822
# Single      0.389355
# Unknown     0.073961
# Divorced    0.073862
# Name: Marital_Status, dtype: float64

# %%
creditcard['Card_Category'].value_counts(normalize=True)
# Out:
# Blue        0.931767
# Silver      0.054804
# Gold        0.011455
# Platinum    0.001975
# Name: Card_Category, dtype: float64

# %%
creditcard['Attrition_Flag'].value_counts(normalize=True)
# Out:
# Existing Customer    0.83934
# Attrited Customer    0.16066
# Name: Attrition_Flag, dtype: float64

# %%
plt.rcParams["figure.figsize"] = (18, 7)
creditcard['Months_on_book'].value_counts().sort_index(ascending=True).plot(kind='bar', title='Months on book');

# %% [markdown]
# Veiem que fa 36 mesos es va produir una gran captació de clients. potser una fusió bancària o una promoció agresiva.
# S'observa una distribució unimodal, simètrica, amb la mitja i mediana molt similars.
# Si fos el gestor del banc estaria preocupat per la clara desaceleració continuada en la contractació de de nous clients desde fa 36 mesos. No tenim dades de clients mes nous dels 13 mesos, no sabem si han invertit la tendència

# %%
sns.displot(x='Transaction_Amount', data=creditcard, height=6, aspect=2);

# %% [markdown]
# Sembla una distribució amb 4-modal

# %% [markdown]
# Generem una **mostra aleatoria simple** agafant el 10% del registres

# %%
sample_aleatoria_10 = creditcard.sample(1014)
sample_aleatoria_10
# Out:
#       CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 6577  714960408  Attrited Customer            44      F                3
# 2969  715921758  Existing Customer            36      M                2
# 7701  717773433  Existing Customer            57      F                0
# 9290  716247708  Existing Customer            51      M                4
# 5212  708681708  Attrited Customer            51      F                2
# ...         ...                ...           ...    ...              ...
# 3494  796791258  Existing Customer            50      M                1
# 8788  769152783  Attrited Customer            60      F                2
# 1619  710263608  Existing Customer            53      F                3
# 6632  780567408  Existing Customer            47      F                3
# 1332  827888433  Existing Customer            43      M                4
#
#      Education_Level Marital_Status Income_Category Card_Category  \
# 6577         College         Single  Less than $40K          Blue
# 2969         College         Single     $60K - $80K          Blue
# 7701        Graduate        Married  Less than $40K          Blue
# 9290         College         Single         $120K +          Gold
# 5212         Unknown         Single  Less than $40K          Blue
# ...              ...            ...             ...           ...
# 3494      Uneducated        Married         $120K +          Blue
# 8788     High School         Single  Less than $40K          Blue
# 1619     High School        Married         Unknown          Blue
# 6632        Graduate       Divorced  Less than $40K          Blue
# 1332      Uneducated         Single     $40K - $60K          Blue
#
#       Months_on_book  Total_Products  Months_Inactive  Contacts_Count  \
# 6577              34               4                3               1
# 2969              25               5                3               2
# 7701              45               6                1               2
# 9290              33               2                2               2
# 5212              43               5                3               2
# ...              ...             ...              ...             ...
# 3494              44               5                2               4
# 8788              54               1                6               2
# 1619              36               4                2               4
# 6632              38               5                1               2
# 1332              39               5                2               2
#
#       Credit_Limit  Revolving  Open_To_Buy  Transaction_Amount  \
# 6577        1605.0        890        715.0                2722
# 2969        1438.3          0       1438.3                2882
# 7701        2448.0          0       2448.0                5464
# 9290       34516.0       1848      32668.0               14149
# 5212        3245.0          0       3245.0                1977
# ...            ...        ...          ...                 ...
# 3494        3104.0       1791       1313.0                4006
# 8788        8141.0       1811       6330.0                5043
# 1619       11098.0        821      10277.0                2156
# 6632        3027.0       1671       1356.0                3912
# 1332        6648.0       2242       4406.0                2089
#
#       Transaction_Count  Utilization_Ratio
# 6577                 45              0.555
# 2969                 68              0.000
# 7701                 98              0.000
# 9290                103              0.054
# 5212                 29              0.000
# ...                 ...                ...
# 3494                 76              0.577
# 8788                 53              0.222
# 1619                 46              0.074
# 6632                 77              0.552
# 1332                 60              0.337
#
# [1014 rows x 19 columns]

# %% [markdown]
# Generem una mostra sistemàtica d'aproximadament un 10% dels registres

# %%
inici = np.random.randint(1, 10)
sample_systematic_10 = creditcard[inici : len(creditcard) : 10]
sample_systematic_10
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 5      713061558  Existing Customer            44      M                2
# 15     714885258  Existing Customer            44      M                4
# 25     771071958  Existing Customer            41      F                3
# 35     715318008  Existing Customer            55      F                1
# 45     712661433  Existing Customer            49      M                4
# ...          ...                ...           ...    ...              ...
# 10085  717714633  Existing Customer            49      M                3
# 10095  789023508  Existing Customer            46      M                3
# 10105  709646433  Attrited Customer            59      F                1
# 10115  712210458  Existing Customer            38      M                1
# 10125  717406983  Attrited Customer            30      M                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 5            Graduate        Married     $40K - $60K          Blue
# 15            Unknown        Unknown    $80K - $120K          Blue
# 25           Graduate         Single  Less than $40K          Blue
# 35            College         Single  Less than $40K          Blue
# 45         Uneducated         Single    $80K - $120K          Blue
# ...               ...            ...             ...           ...
# 10085      Uneducated        Married         $120K +          Gold
# 10095         Unknown        Married    $80K - $120K          Blue
# 10105     High School        Married  Less than $40K          Blue
# 10115      Uneducated         Single     $40K - $60K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
#
#        Months_on_book  Total_Products  Months_Inactive  Contacts_Count  \
# 5                  36               3                1               2
# 15                 37               5                1               2
# 25                 28               6                1               2
# 35                 36               4                2               1
# 45                 30               3                2               3
# ...               ...             ...              ...             ...
# 10085              38               4                3               4
# 10095              33               4                1               3
# 10105              50               1                4               3
# 10115              36               2                3               2
# 10125              36               4                3               3
#
#        Credit_Limit  Revolving  Open_To_Buy  Transaction_Amount  \
# 5            4010.0       1247       2763.0                1088
# 15           4234.0        972       3262.0                1348
# 25           7768.0       1669       6099.0                1051
# 35           3520.0       1914       1606.0                1407
# 45          34516.0          0      34516.0                1444
# ...             ...        ...          ...                 ...
# 10085       14938.0          0      14938.0               15277
# 10095       34516.0       1099      33417.0               15490
# 10105        5043.0        743       4300.0               10170
# 10115        5639.0       1558       4081.0               16628
# 10125        5281.0          0       5281.0                8395
#
#        Transaction_Count  Utilization_Ratio
# 5                     24              0.311
# 15                    27              0.230
# 25                    22              0.215
# 35                    43              0.544
# 45                    28              0.000
# ...                  ...                ...
# 10085                131              0.000
# 10095                110              0.032
# 10105                 66              0.147
# 10115                109              0.276
# 10125                 62              0.000
#
# [1013 rows x 19 columns]

# %% [markdown]
# Per tal de fer una avaluació de la bondat de les 2 mostres, comparem la mitjana de cada mostra amb la mitjana del total de la població

# %%
comparativa=pd.concat([creditcard.mean(),sample_aleatoria_10.mean(), sample_systematic_10.mean()], keys=['poblacio','mostra_aleatoria','mostra_sistemica'],axis=1)
comparativa
# Out:
# C:\Users\joseb\AppData\Local\Temp/ipykernel_4888/423228879.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   comparativa=pd.concat([creditcard.mean(),sample_aleatoria_10.mean(), sample_systematic_10.mean()], keys=['poblacio','mostra_aleatoria','mostra_sistemica'],axis=1)
#                         poblacio  mostra_aleatoria  mostra_sistemica
# CLIENTNUM           7.391776e+08      7.383346e+08      7.394867e+08
# Customer_Age        4.632596e+01      4.630868e+01      4.630997e+01
# Dependent_count     2.346203e+00      2.404339e+00      2.322804e+00
# Months_on_book      3.592841e+01      3.589842e+01      3.602172e+01
# Total_Products      3.812580e+00      3.835306e+00      3.787759e+00
# Months_Inactive     2.341167e+00      2.315582e+00      2.405726e+00
# Contacts_Count      2.455317e+00      2.515779e+00      2.511352e+00
# Credit_Limit        8.631954e+03      8.101983e+03      8.757829e+03
# Revolving           1.162814e+03      1.124204e+03      1.123293e+03
# Open_To_Buy         7.469140e+03      6.977779e+03      7.634535e+03
# Transaction_Amount  4.404086e+03      4.389553e+03      4.428838e+03
# Transaction_Count   6.485869e+01      6.477811e+01      6.476505e+01
# Utilization_Ratio   2.748936e-01      2.743994e-01      2.636890e-01

# %% [markdown]
# Afegim 2 columnes amb el increment porcentual de cada mostreig respecte a la població total

# %%
comparativa['inc_aleatoria %'] = (comparativa.mostra_aleatoria - comparativa.poblacio)*100/comparativa.poblacio
comparativa['inc_sistemica %'] = (comparativa.mostra_sistemica - comparativa.poblacio)*100/comparativa.poblacio
comparativa
# Out:
#                         poblacio  mostra_aleatoria  mostra_sistemica  \
# CLIENTNUM           7.391776e+08      7.383346e+08      7.394867e+08
# Customer_Age        4.632596e+01      4.630868e+01      4.630997e+01
# Dependent_count     2.346203e+00      2.404339e+00      2.322804e+00
# Months_on_book      3.592841e+01      3.589842e+01      3.602172e+01
# Total_Products      3.812580e+00      3.835306e+00      3.787759e+00
# Months_Inactive     2.341167e+00      2.315582e+00      2.405726e+00
# Contacts_Count      2.455317e+00      2.515779e+00      2.511352e+00
# Credit_Limit        8.631954e+03      8.101983e+03      8.757829e+03
# Revolving           1.162814e+03      1.124204e+03      1.123293e+03
# Open_To_Buy         7.469140e+03      6.977779e+03      7.634535e+03
# Transaction_Amount  4.404086e+03      4.389553e+03      4.428838e+03
# Transaction_Count   6.485869e+01      6.477811e+01      6.476505e+01
# Utilization_Ratio   2.748936e-01      2.743994e-01      2.636890e-01
#
#                     inc_aleatoria %  inc_sistemica %
# CLIENTNUM                 -0.114041         0.041815
# Customer_Age              -0.037305        -0.034516
# Dependent_count            2.477877        -0.997342
# Months_on_book            -0.083464         0.259707
# Total_Products             0.596066        -0.651032
# Months_Inactive           -1.092845         2.757530
# Contacts_Count             2.462477         2.282188
# Credit_Limit              -6.139634         1.458243
# Revolving                 -3.320386        -3.398727
# Open_To_Buy               -6.578541         2.214388
# Transaction_Amount        -0.329990         0.562019
# Transaction_Count         -0.124252        -0.144376
# Utilization_Ratio         -0.179758        -4.075945

# %%
comparativa[['inc_aleatoria %','inc_sistemica %']].abs().mean()
# Out:
# inc_aleatoria %    1.81051
# inc_sistemica %    1.45214
# dtype: float64

# %% [markdown]
# De la comparació de la mitjana de les diferents variables entre les dues mostres i el total de la població tenim:
# - Les diferències percentuals de les mitjes de les diferents variables respecte a les mostres és inferior al 4,1%
# - La mostra aleatoria i la mostra sistèmica presenten un error similar respecte a la població.

# %% [markdown]
# ## - Exercici 2
#
# Continua amb el conjunt de dades de tema esportiu i genera una mostra estratificada i una mostra utilitzant SMOTE (Synthetic Minority Oversampling Technique).

# %% [markdown]
# A l'exercici anterior hem vist les distribucions de les diferents variables.
# Teninm 6 variables susceptibles d'estratificar : Gender, Education_Level, Income_Category, Card_Category, attritio_Flag i Marital_Status.
# Descartem Gender perque el nombre d'observacions dels estrats són similars.
# Sense altre informació de com poden influir els estrats de dels diferents variables, agafarem per estratificar **Income_Category** perquè probablement el nivell d'ingressos afecti als diferents ratis bancaris

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest = train_test_split(creditcard, test_size=0.10, stratify=creditcard[['Income_Category']])
Xtest
# Out:
#       CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 3293  814489683  Existing Customer            34      F                2
# 2247  797753283  Existing Customer            34      F                1
# 9846  758753283  Attrited Customer            52      M                3
# 5523  720941433  Attrited Customer            53      F                3
# 2607  755943033  Existing Customer            34      F                2
# ...         ...                ...           ...    ...              ...
# 1877  717585858  Existing Customer            35      F                4
# 9501  789394833  Existing Customer            47      M                2
# 570   709040508  Existing Customer            57      M                4
# 2840  803231058  Existing Customer            53      M                3
# 5347  779491908  Existing Customer            47      F                4
#
#      Education_Level Marital_Status Income_Category Card_Category  \
# 3293         Unknown         Single  Less than $40K          Blue
# 2247     High School        Married  Less than $40K          Blue
# 9846       Doctorate        Married         $120K +          Blue
# 5523     High School        Married  Less than $40K          Blue
# 2607        Graduate         Single  Less than $40K          Blue
# ...              ...            ...             ...           ...
# 1877     High School         Single         Unknown          Blue
# 9501         Unknown       Divorced    $80K - $120K          Blue
# 570       Uneducated        Married         $120K +          Blue
# 2840     High School         Single  Less than $40K          Blue
# 5347   Post-Graduate        Unknown         Unknown          Blue
#
#       Months_on_book  Total_Products  Months_Inactive  Contacts_Count  \
# 3293              29               3                1               0
# 2247              28               4                3               4
# 9846              45               1                3               3
# 5523              41               3                3               2
# 2607              27               4                1               1
# ...              ...             ...              ...             ...
# 1877              24               5                2               4
# 9501              37               1                2               2
# 570               38               6                6               2
# 2840              47               5                1               1
# 5347              29               5                2               1
#
#       Credit_Limit  Revolving  Open_To_Buy  Transaction_Amount  \
# 3293        5387.0        795       4592.0                2596
# 2247        2707.0       2036        671.0                1926
# 9846       34516.0        550      33966.0                7341
# 5523        1547.0          0       1547.0                2312
# 2607        1901.0       1176        725.0                2450
# ...            ...        ...          ...                 ...
# 1877       16915.0       1679      15236.0                2795
# 9501       21714.0       1969      19745.0               13270
# 570        19802.0       1961      17841.0                2244
# 2840        3351.0       1474       1877.0                4294
# 5347        8644.0       1391       7253.0                4272
#
#       Transaction_Count  Utilization_Ratio
# 3293                 59              0.148
# 2247                 33              0.752
# 9846                 71              0.016
# 5523                 43              0.000
# 2607                 52              0.619
# ...                 ...                ...
# 1877                 55              0.099
# 9501                104              0.091
# 570                  58              0.099
# 2840                 66              0.440
# 5347                 59              0.161
#
# [1013 rows x 19 columns]

# %% [markdown]
# Anem a comprobar si la mostra amb el stratify segueix els percentatges de la població

# %%
pd.concat([creditcard['Income_Category'].value_counts(normalize=True), Xtest['Income_Category'].value_counts(normalize=True)], keys=['poblacio','mostra_estratificada'],axis=1)
# Out:
#                 poblacio  mostra_estratificada
# Less than $40K  0.351634              0.351431
# $40K - $60K     0.176755              0.176703
# $80K - $120K    0.151575              0.152024
# $60K - $80K     0.138442              0.138203
# Unknown         0.109805              0.109576
# $120K +         0.071788              0.072063

# %% [markdown]
# **Efectivament!!!** La mostra estratificada té la mateixa distribució en quant a **Income_Category** que la població

# %% [markdown]
# Fem **smote**. Instalem el mòdul **imbalanced_learn**

# %%
import imblearn
from imblearn.over_sampling import SMOTE

# %% [markdown]
# Creem un nou dataframe on no tinguem columnes string, excepte la columna que anem a balancejar (Attrion_Flag)

# %%
creditcard_smote=creditcard.drop(creditcard.columns[[0,3,5,6,7,8]], axis='columns')
creditcard_smote
# Out:
#           Attrition_Flag  Customer_Age  Dependent_count  Months_on_book  \
# 0      Existing Customer            45                3              39
# 1      Existing Customer            49                5              44
# 2      Existing Customer            51                3              36
# 3      Existing Customer            40                4              34
# 4      Existing Customer            40                3              21
# ...                  ...           ...              ...             ...
# 10122  Existing Customer            50                2              40
# 10123  Attrited Customer            41                2              25
# 10124  Attrited Customer            44                1              36
# 10125  Attrited Customer            30                2              36
# 10126  Attrited Customer            43                2              25
#
#        Total_Products  Months_Inactive  Contacts_Count  Credit_Limit  \
# 0                   5                1               3       12691.0
# 1                   6                1               2        8256.0
# 2                   4                1               0        3418.0
# 3                   3                4               1        3313.0
# 4                   5                1               0        4716.0
# ...               ...              ...             ...           ...
# 10122               3                2               3        4003.0
# 10123               4                2               3        4277.0
# 10124               5                3               4        5409.0
# 10125               4                3               3        5281.0
# 10126               6                2               4       10388.0
#
#        Revolving  Open_To_Buy  Transaction_Amount  Transaction_Count  \
# 0            777      11914.0                1144                 42
# 1            864       7392.0                1291                 33
# 2              0       3418.0                1887                 20
# 3           2517        796.0                1171                 20
# 4              0       4716.0                 816                 28
# ...          ...          ...                 ...                ...
# 10122       1851       2152.0               15476                117
# 10123       2186       2091.0                8764                 69
# 10124          0       5409.0               10291                 60
# 10125          0       5281.0                8395                 62
# 10126       1961       8427.0               10294                 61
#
#        Utilization_Ratio
# 0                  0.061
# 1                  0.105
# 2                  0.000
# 3                  0.760
# 4                  0.000
# ...                  ...
# 10122              0.462
# 10123              0.511
# 10124              0.000
# 10125              0.000
# 10126              0.189
#
# [10127 rows x 13 columns]

# %% [markdown]
# Transformem Attrition_Flag segons els seus valors: Existing Customer=0, Attritied Customer=1

# %%
creditcard_smote['Attrition_Flag'].value_counts()
# Out:
# Existing Customer    8500
# Attrited Customer    1627
# Name: Attrition_Flag, dtype: int64

# %%
#Transformem Attrition_Flag segons els seus valors: Existing Customer=0, Attritied Customer=1
creditcard_smote['Attrition_Flag'] = creditcard_smote['Attrition_Flag'].apply(lambda x: 0 if x=='Existing Customer' else 1)
creditcard_smote
# Out:
#        Attrition_Flag  Customer_Age  Dependent_count  Months_on_book  \
# 0                   0            45                3              39
# 1                   0            49                5              44
# 2                   0            51                3              36
# 3                   0            40                4              34
# 4                   0            40                3              21
# ...               ...           ...              ...             ...
# 10122               0            50                2              40
# 10123               1            41                2              25
# 10124               1            44                1              36
# 10125               1            30                2              36
# 10126               1            43                2              25
#
#        Total_Products  Months_Inactive  Contacts_Count  Credit_Limit  \
# 0                   5                1               3       12691.0
# 1                   6                1               2        8256.0
# 2                   4                1               0        3418.0
# 3                   3                4               1        3313.0
# 4                   5                1               0        4716.0
# ...               ...              ...             ...           ...
# 10122               3                2               3        4003.0
# 10123               4                2               3        4277.0
# 10124               5                3               4        5409.0
# 10125               4                3               3        5281.0
# 10126               6                2               4       10388.0
#
#        Revolving  Open_To_Buy  Transaction_Amount  Transaction_Count  \
# 0            777      11914.0                1144                 42
# 1            864       7392.0                1291                 33
# 2              0       3418.0                1887                 20
# 3           2517        796.0                1171                 20
# 4              0       4716.0                 816                 28
# ...          ...          ...                 ...                ...
# 10122       1851       2152.0               15476                117
# 10123       2186       2091.0                8764                 69
# 10124          0       5409.0               10291                 60
# 10125          0       5281.0                8395                 62
# 10126       1961       8427.0               10294                 61
#
#        Utilization_Ratio
# 0                  0.061
# 1                  0.105
# 2                  0.000
# 3                  0.760
# 4                  0.000
# ...                  ...
# 10122              0.462
# 10123              0.511
# 10124              0.000
# 10125              0.000
# 10126              0.189
#
# [10127 rows x 13 columns]

# %%
creditcard_smote.Attrition_Flag.value_counts()
# Out:
# 0    8500
# 1    1627
# Name: Attrition_Flag, dtype: int64

# %%
smote = SMOTE(sampling_strategy = 'minority')
X_smote, y_smote = smote.fit_resample(creditcard_smote, creditcard_smote['Attrition_Flag'])

# %%
X_smote
# Out:
#        Attrition_Flag  Customer_Age  Dependent_count  Months_on_book  \
# 0                   0            45                3              39
# 1                   0            49                5              44
# 2                   0            51                3              36
# 3                   0            40                4              34
# 4                   0            40                3              21
# ...               ...           ...              ...             ...
# 16995               1            41                2              31
# 16996               1            50                1              35
# 16997               1            33                1              24
# 16998               1            41                1              35
# 16999               1            52                1              42
#
#        Total_Products  Months_Inactive  Contacts_Count  Credit_Limit  \
# 0                   5                1               3  12691.000000
# 1                   6                1               2   8256.000000
# 2                   4                1               0   3418.000000
# 3                   3                4               1   3313.000000
# 4                   5                1               0   4716.000000
# ...               ...              ...             ...           ...
# 16995               3                2               2   1820.221702
# 16996               3                3               2   8570.245023
# 16997               2                2               3   6072.926920
# 16998               3                2               3   1586.552643
# 16999               4                2               3  14662.586795
#
#        Revolving   Open_To_Buy  Transaction_Amount  Transaction_Count  \
# 0            777  11914.000000                1144                 42
# 1            864   7392.000000                1291                 33
# 2              0   3418.000000                1887                 20
# 3           2517    796.000000                1171                 20
# 4              0   4716.000000                 816                 28
# ...          ...           ...                 ...                ...
# 16995       1370    449.431665                2098                 51
# 16996       2507   6062.755535                7875                 70
# 16997          0   6072.926920                9291                 60
# 16998        263   1322.643624                2296                 45
# 16999          0  14662.586795                1229                 25
#
#        Utilization_Ratio
# 0               0.061000
# 1               0.105000
# 2               0.000000
# 3               0.760000
# 4               0.000000
# ...                  ...
# 16995           0.754003
# 16996           0.293152
# 16997           0.000000
# 16998           0.166241
# 16999           0.000000
#
# [17000 rows x 13 columns]

# %%
X_smote.Attrition_Flag.value_counts()
# Out:
# 0    8500
# 1    8500
# Name: Attrition_Flag, dtype: int64

# %% [markdown]
# Podem comprobar que ha augmentat els Attrited Customer fins als 8500 per que siguin els mateixos que de Existing Customer

# %% [markdown]
# ## - Exercici 3
#
# Continua amb el conjunt de dades de tema esportiu i genera una mostra utilitzant el mètode Reservoir sampling.

# %% [markdown]
# A partir de l'algoritme suministrat per aplicar el mètode Reservoir sampling, l'adapto segons:
# - El generador que utilitzo és l'iterable range(), que em genera números consecutius des del 0 fins a la longitut del DF
# - En reservoir guardo el números generats que corresponguin segons el mètodo Reservoir sampling
# - Faig servir els números guardats a reservoir com a index dels registres del sampling
# - El tamany del sample serà del 10% de la població
#
# Es a dir, simulo que em van arribant els registres des de el primer fins a l'últim i els aplico el Reservoir sampling

# %%
import random

k=int(len(creditcard)*0.1)                    #Agafa una mostra del 10%
print('sampling size: {0}'.format(k))
reservoir = []
for i in range(len(creditcard)):
    if i+1<= k:
        reservoir.append(i)
    else:
        probability = k/(i+1)
        if random.random() < probability:
            reservoir[random.choice(range(0,k))] = i
reservoir
# Out:
# sampling size: 1012
# [4093,
#  9907,
#  1712,
#  1221,
#  1361,
#  1947,
#  6628,
#  2347,
#  3403,
#  8574,
#  4538,
#  11,
#  1933,
#  7048,
#  10108,
#  6364,
#  8140,
#  2859,
#  3088,
#  9511,
#  6404,
#  6751,
#  1384,
#  5328,
#  8520,
#  3312,
#  26,
#  9946,
#  9654,
#  2893,
#  7144,
#  1802,
#  9606,
#  9044,
#  7950,
#  5297,
#  2570,
#  9111,
#  4785,
#  8640,
#  2204,
#  41,
#  2133,
#  6127,
#  9232,
#  4461,
#  2612,
#  9903,
#  2648,
#  3591,
#  9068,
#  4100,
#  1996,
#  5141,
#  1763,
#  6935,
#  6369,
#  5767,
#  9169,
#  3504,
#  6174,
#  61,
#  6807,
#  2222,
#  64,
#  4299,
#  9776,
#  4989,
#  9115,
#  5703,
#  9048,
#  1642,
#  1768,
#  3782,
#  2235,
#  5705,
#  76,
#  6480,
#  5530,
#  7631,
#  5624,
#  2776,
#  2979,
#  2372,
#  3561,
#  8158,
#  2736,
#  3374,
#  1979,
#  1254,
#  1918,
#  2962,
#  92,
#  7784,
#  9190,
#  3205,
#  8161,
#  4765,
#  7096,
#  7756,
#  7539,
#  3334,
#  102,
#  4502,
#  104,
#  5840,
#  5233,
#  7114,
#  5105,
#  1610,
#  110,
#  6816,
#  2209,
#  7104,
#  2863,
#  1992,
#  3370,
#  5485,
#  7582,
#  6073,
#  2153,
#  10056,
#  1535,
#  2580,
#  3306,
#  2069,
#  126,
#  1226,
#  9266,
#  1607,
#  8912,
#  2870,
#  132,
#  8817,
#  3986,
#  135,
#  8182,
#  8117,
#  8284,
#  4355,
#  2384,
#  4549,
#  6995,
#  3617,
#  1131,
#  7020,
#  1354,
#  8137,
#  8553,
#  1443,
#  3992,
#  2498,
#  9883,
#  2353,
#  1621,
#  8548,
#  2623,
#  6253,
#  6980,
#  3005,
#  2896,
#  2905,
#  2467,
#  1708,
#  3101,
#  4508,
#  3251,
#  2874,
#  5216,
#  9245,
#  9213,
#  7092,
#  8148,
#  2728,
#  7313,
#  5361,
#  8837,
#  8449,
#  9524,
#  7394,
#  180,
#  6226,
#  5573,
#  3542,
#  3850,
#  9570,
#  6909,
#  8599,
#  5874,
#  5032,
#  190,
#  7770,
#  2514,
#  9849,
#  8609,
#  2364,
#  1685,
#  7132,
#  1153,
#  3277,
#  8426,
#  6441,
#  9163,
#  203,
#  1095,
#  2359,
#  8138,
#  207,
#  1129,
#  3339,
#  4039,
#  211,
#  5342,
#  8019,
#  2366,
#  2954,
#  6630,
#  8630,
#  5401,
#  1939,
#  3171,
#  6600,
#  2349,
#  223,
#  224,
#  9839,
#  3423,
#  227,
#  6731,
#  6530,
#  4840,
#  8291,
#  3456,
#  8370,
#  234,
#  9986,
#  3133,
#  9692,
#  2842,
#  3284,
#  5757,
#  4946,
#  9955,
#  2394,
#  6234,
#  5911,
#  2673,
#  6735,
#  3711,
#  6933,
#  250,
#  6523,
#  9501,
#  9637,
#  6416,
#  7482,
#  4250,
#  6150,
#  2333,
#  3190,
#  3536,
#  261,
#  5002,
#  1894,
#  5578,
#  7423,
#  2219,
#  2708,
#  268,
#  269,
#  8815,
#  5941,
#  272,
#  6765,
#  1439,
#  7186,
#  8178,
#  3641,
#  9211,
#  4569,
#  9759,
#  4297,
#  3375,
#  5558,
#  5265,
#  5964,
#  9107,
#  9371,
#  3913,
#  7182,
#  5374,
#  2616,
#  4199,
#  7620,
#  10077,
#  8812,
#  6806,
#  7043,
#  9305,
#  4235,
#  5372,
#  9097,
#  1021,
#  6292,
#  8316,
#  3790,
#  3271,
#  6275,
#  8037,
#  2363,
#  5883,
#  8002,
#  5009,
#  9175,
#  6087,
#  2807,
#  316,
#  317,
#  9122,
#  6313,
#  4221,
#  2644,
#  9674,
#  323,
#  7373,
#  9464,
#  2861,
#  9977,
#  6173,
#  329,
#  9367,
#  5235,
#  2304,
#  6287,
#  8079,
#  9473,
#  3812,
#  337,
#  8406,
#  8742,
#  8713,
#  8311,
#  5679,
#  1315,
#  5537,
#  3660,
#  3159,
#  4475,
#  348,
#  349,
#  2395,
#  351,
#  9965,
#  7432,
#  2509,
#  7256,
#  6149,
#  10022,
#  3533,
#  4333,
#  6111,
#  7871,
#  4674,
#  5228,
#  364,
#  2174,
#  5188,
#  3168,
#  7054,
#  6740,
#  2296,
#  371,
#  5721,
#  373,
#  3414,
#  5164,
#  10106,
#  6621,
#  7928,
#  2910,
#  8363,
#  7280,
#  6808,
#  2686,
#  1879,
#  2998,
#  2897,
#  1127,
#  5605,
#  7710,
#  5977,
#  4509,
#  3706,
#  4847,
#  7892,
#  5220,
#  396,
#  9921,
#  2208,
#  2890,
#  400,
#  8637,
#  1784,
#  2408,
#  3230,
#  3270,
#  9165,
#  7451,
#  2088,
#  5809,
#  4316,
#  3710,
#  7927,
#  4630,
#  414,
#  6762,
#  1632,
#  2777,
#  7266,
#  419,
#  9082,
#  9223,
#  4762,
#  3513,
#  4795,
#  1870,
#  4472,
#  3662,
#  7376,
#  8317,
#  430,
#  7956,
#  6280,
#  9130,
#  2138,
#  6991,
#  1673,
#  9610,
#  5607,
#  8894,
#  3219,
#  2573,
#  5145,
#  5276,
#  7032,
#  7648,
#  2131,
#  5781,
#  5698,
#  1647,
#  2485,
#  9706,
#  1258,
#  8595,
#  6236,
#  5970,
#  3552,
#  1734,
#  2694,
#  7485,
#  4980,
#  3489,
#  8371,
#  3635,
#  9457,
#  465,
#  5158,
#  467,
#  8634,
#  5858,
#  1448,
#  1900,
#  5439,
#  473,
#  10065,
#  475,
#  5022,
#  9676,
#  1563,
#  9552,
#  1044,
#  8844,
#  482,
#  5110,
#  8269,
#  485,
#  8875,
#  1069,
#  2189,
#  5246,
#  8571,
#  9823,
#  6179,
#  7034,
#  4809,
#  8796,
#  496,
#  7925,
#  9275,
#  1862,
#  9665,
#  3804,
#  2987,
#  8514,
#  5376,
#  1211,
#  3595,
#  6343,
#  1648,
#  2281,
#  3126,
#  511,
#  9664,
#  8120,
#  3303,
#  9577,
#  516,
#  6192,
#  2245,
#  2717,
#  520,
#  3643,
#  7465,
#  6997,
#  9458,
#  7783,
#  9958,
#  8100,
#  3905,
#  529,
#  1220,
#  6091,
#  532,
#  3972,
#  1054,
#  9108,
#  8560,
#  6097,
#  4416,
#  6884,
#  9770,
#  8545,
#  4255,
#  1994,
#  544,
#  2803,
#  9046,
#  5731,
#  2095,
#  8840,
#  1174,
#  5082,
#  6184,
#  8932,
#  5895,
#  4102,
#  1865,
#  557,
#  3764,
#  8955,
#  2437,
#  1989,
#  3010,
#  3117,
#  564,
#  2046,
#  2149,
#  1699,
#  7673,
#  9229,
#  3620,
#  5843,
#  9914,
#  8728,
#  5318,
#  575,
#  3837,
#  6424,
#  9725,
#  4018,
#  2443,
#  7419,
#  3929,
#  7443,
#  8552,
#  4685,
#  6496,
#  8297,
#  8084,
#  6567,
#  7531,
#  8522,
#  7667,
#  4756,
#  9579,
#  1634,
#  2848,
#  4428,
#  1449,
#  599,
#  4433,
#  9808,
#  2627,
#  8323,
#  3355,
#  6820,
#  2481,
#  607,
#  6075,
#  6896,
#  3735,
#  5227,
#  1880,
#  7839,
#  4714,
#  615,
#  5036,
#  1813,
#  5415,
#  8010,
#  9709,
#  2261,
#  2044,
#  8343,
#  6466,
#  625,
#  8707,
#  6761,
#  628,
#  6540,
#  1654,
#  8481,
#  1913,
#  633,
#  634,
#  2268,
#  8016,
#  9166,
#  10117,
#  7906,
#  9176,
#  7068,
#  1180,
#  643,
#  3061,
#  9162,
#  646,
#  1270,
#  4197,
#  5780,
#  8055,
#  3252,
#  8509,
#  3959,
#  4526,
#  7010,
#  3161,
#  6782,
#  658,
#  6209,
#  2303,
#  9649,
#  7072,
#  2472,
#  8026,
#  7386,
#  1249,
#  3609,
#  1135,
#  9703,
#  7975,
#  5306,
#  7148,
#  7189,
#  674,
#  9962,
#  1482,
#  7523,
#  9304,
#  4471,
#  9695,
#  7220,
#  9183,
#  7274,
#  3963,
#  6317,
#  6536,
#  4836,
#  9961,
#  4261,
#  4864,
#  1480,
#  1932,
#  7566,
#  4881,
#  4859,
#  9598,
#  6970,
#  7737,
#  5006,
#  3930,
#  9682,
#  9381,
#  2964,
#  2427,
#  9218,
#  2378,
#  4044,
#  8022,
#  3704,
#  4782,
#  4690,
#  5824,
#  8322,
#  7744,
#  3457,
#  1332,
#  9143,
#  1586,
#  8248,
#  9155,
#  1151,
#  6437,
#  6332,
#  7792,
#  725,
#  9754,
#  3245,
#  5716,
#  5299,
#  730,
#  731,
#  3810,
#  5116,
#  8423,
#  8696,
#  3586,
#  9002,
#  738,
#  3996,
#  2598,
#  8807,
#  742,
#  1209,
#  5135,
#  7692,
#  3556,
#  1711,
#  2989,
#  6580,
#  1741,
#  6633,
#  2344,
#  5447,
#  5519,
#  3559,
#  3774,
#  7954,
#  9758,
#  2931,
#  2925,
#  1814,
#  4696,
#  4806,
#  2878,
#  1305,
#  4267,
#  7552,
#  8711,
#  4643,
#  3587,
#  771,
#  4583,
#  1516,
#  6507,
#  8719,
#  9742,
#  1985,
#  1799,
#  9463,
#  9038,
#  1252,
#  782,
#  9811,
#  6464,
#  3964,
#  8584,
#  7789,
#  6967,
#  8225,
#  8508,
#  2012,
#  792,
#  4497,
#  9051,
#  4589,
#  8332,
#  4290,
#  4470,
#  8001,
#  9243,
#  2877,
#  802,
#  3663,
#  8313,
#  8777,
#  8306,
#  807,
#  808,
#  4270,
#  7223,
#  2326,
#  4251,
#  7821,
#  814,
#  8543,
#  6541,
#  6962,
#  818,
#  1803,
#  1689,
#  4699,
#  4269,
#  3110,
#  8619,
#  4047,
#  6949,
#  4746,
#  3614,
#  7876,
#  7614,
#  4768,
#  6137,
#  10037,
#  9968,
#  5890,
#  6901,
#  3564,
#  3540,
#  2935,
#  1204,
#  1544,
#  842,
#  2550,
#  844,
#  6064,
#  846,
#  847,
#  5202,
#  6040,
#  3598,
#  2297,
#  4754,
#  6065,
#  4960,
#  1748,
#  2650,
#  4842,
#  9227,
#  8345,
#  7211,
#  2782,
#  1177,
#  5420,
#  8384,
#  1478,
#  6191,
#  867,
#  5144,
#  8121,
#  6145,
#  871,
#  4156,
#  6563,
#  6263,
#  8429,
#  876,
#  6483,
#  7767,
#  1295,
#  9393,
#  1678,
#  5817,
#  883,
#  9515,
#  5083,
#  886,
#  5453,
#  6772,
#  889,
#  8082,
#  1450,
#  8889,
#  7164,
#  8177,
#  2273,
#  3243,
#  1995,
#  1733,
#  1990,
#  2615,
#  7230,
#  9241,
#  5088,
#  9837,
#  1720,
#  2919,
#  9910,
#  3179,
#  5572,
#  6934,
#  1704,
#  912,
#  7458,
#  9752,
#  7637,
#  7476,
#  1024,
#  4969,
#  4998,
#  7120,
#  6012,
#  1564,
#  2822,
#  1845,
#  3329,
#  4328,
#  7613,
#  8569,
#  4225,
#  5867,
#  1183,
#  2126,
#  7515,
#  5478,
#  6001,
#  3030,
#  5808,
#  5077,
#  9542,
#  8580,
#  5885,
#  6107,
#  943,
#  4490,
#  4748,
#  946,
#  9555,
#  1783,
#  2010,
#  2262,
#  7299,
#  6826,
#  1473,
#  1652,
#  7541,
#  9900,
#  957,
#  3213,
#  1047,
#  9496,
#  3112,
#  962,
#  4117,
#  1818,
#  3292,
#  6443,
#  7734,
#  9510,
#  2127,
#  5339,
#  3845,
#  972,
#  973,
#  4865,
#  6002,
#  976,
#  3721,
#  1205,
#  8085,
#  4002,
#  10063,
#  8296,
#  8923,
#  6555,
#  3397,
#  3206,
#  9722,
#  7746,
#  5131,
#  1367,
#  2934,
#  8260,
#  1775,
#  10033,
#  2814,
#  1052,
#  997,
#  4132,
#  999,
#  ...]

# %%
creditcard.iloc[reservoir]
# Out:
#       CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 4093  713138433  Existing Customer            50      M                3
# 9907  714543633  Attrited Customer            45      F                3
# 1712  772452783  Existing Customer            43      M                3
# 1221  780605508  Existing Customer            53      M                1
# 1361  783364233  Existing Customer            59      M                0
# ...         ...                ...           ...    ...              ...
# 8579  811889808  Existing Customer            43      M                3
# 4124  755593983  Existing Customer            50      F                1
# 2104  795052083  Existing Customer            63      F                0
# 3824  785134758  Existing Customer            41      M                2
# 3438  713750583  Existing Customer            55      F                1
#
#      Education_Level Marital_Status Income_Category Card_Category  \
# 4093        Graduate         Single     $60K - $80K          Blue
# 9907         Unknown         Single  Less than $40K          Blue
# 1712         Unknown        Married     $40K - $60K          Blue
# 1221         Unknown        Married     $40K - $60K          Blue
# 1361        Graduate        Married     $40K - $60K          Blue
# ...              ...            ...             ...           ...
# 8579        Graduate        Married    $80K - $120K          Blue
# 4124        Graduate        Married         Unknown          Blue
# 2104      Uneducated         Single     $40K - $60K          Blue
# 3824         College        Unknown    $80K - $120K          Blue
# 3438         College        Unknown  Less than $40K          Blue
#
#       Months_on_book  Total_Products  Months_Inactive  Contacts_Count  \
# 4093              42               4                2               3
# 9907              36               1                2               5
# 1712              33               6                1               2
# 1221              41               5                1               3
# 1361              53               3                2               3
# ...              ...             ...              ...             ...
# 8579              38               3                5               1
# 4124              43               6                1               2
# 2104              56               3                6               4
# 3824              24               3                2               4
# 3438              36               4                2               4
#
#       Credit_Limit  Revolving  Open_To_Buy  Transaction_Amount  \
# 4093       14782.0       1020      13762.0                3206
# 9907        7500.0          0       7500.0                8024
# 1712        4402.0       1640       2762.0                1774
# 1221        2885.0       1433       1452.0                1170
# 1361        4241.0          0       4241.0                1798
# ...            ...        ...          ...                 ...
# 8579       23459.0       2305      21154.0                7279
# 4124        7985.0          0       7985.0                3873
# 2104        1438.3          0       1438.3                3630
# 3824       14320.0          0      14320.0                4077
# 3438        1928.0       1125        803.0                2190
#
#       Transaction_Count  Utilization_Ratio
# 4093                 54              0.069
# 9907                 78              0.000
# 1712                 46              0.373
# 1221                 23              0.497
# 1361                 45              0.000
# ...                 ...                ...
# 8579                 83              0.098
# 4124                 72              0.000
# 2104                 71              0.000
# 3824                 77              0.000
# 3438                 30              0.584
#
# [1012 rows x 19 columns]
